# %% [markdown]
# <a href="https://colab.research.google.com/github/AaronVincent6411/Power-Line-Supply-BlackBox--Detection/blob/main/Power_Supply_Black_box_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.2/716.2 kB 10.0 MB/s eta 0:00:00
# ...

# %%
# !kaggle datasets download -d aaronvincent6411/power-supply-line-black-box
# Out:
# ...
#  93% 149M/160M [00:01<00:00, 109MB/s]
# 100% 160M/160M [00:01<00:00, 105MB/s]

# %%
# !unzip --qq /content/power-supply-line-black-box.zip

# %%
# !yolo train model=yolov8m.pt data=/content/data.yaml epochs=50 imgsz=640
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 299MB/s]
# Ultralytics YOLOv8.1.19 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
